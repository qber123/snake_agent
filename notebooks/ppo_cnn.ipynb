# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))
from snake.snake_gym import Snake

from gymnasium.wrappers import FrameStackObservation, RecordVideo, RecordEpisodeStatistics
from gymnasium.vector import SyncVectorEnv

import numpy as np

import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter

import time
import matplotlib.pyplot as plt

# %%
train_video_dir = f"../data/ppo/v1"
train_episodes = 1000
num_steps = 2048
num_envs = 8
stack_size = 4

# %%
def make_env(idx: int, capture_video: bool = False):
    def thunk():
        env = Snake(truncation_steps=25000)
        
        env = FrameStackObservation(env, stack_size=stack_size)        
        env = RecordEpisodeStatistics(env=env)
        
        if capture_video and idx == 0:
            env = RecordVideo(env, train_video_dir, episode_trigger=lambda episode_id: episode_id % 100 == 0)
        return env
    return thunk

# %%
envs = SyncVectorEnv([make_env(idx, capture_video=False) for idx in range(num_envs)])

# %%
action_size = envs.single_action_space.n
action_size
# Out:
# np.int64(4)

# %%
envs.single_observation_space
# Out:
# Box(0.0, 3.0, (4, 30, 30), float32)

# %%
obs, _ = envs.reset(seed=42)
obs[0][0]

for i in range(100):
    obs, reward, terminations, truncations, infos = envs.step(envs.action_space.sample())
    print(infos)
        
    
plt.imshow(obs[0][0])
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'episode': {'r': array([0., 0., 1., 0., 0., 0., 0., 0.]), '_r': array([False, False,  True, False, False, False, False, False]), 'l': array([ 0,  0, 30,  0,  0,  0,  0,  0]), '_l': array([False, False,  True, False, False, False, False, False]), 't': array([0.      , 0.      , 0.009287, 0.      , 0.      , 0.      ,
#        0.      , 0.      ]), '_t': array([False, False,  True, False, False, False, False, False])}, '_episode': array([False, False,  True, False, False, False, False, False])}
# {'episode': {'r': array([0., 0., 0., 0., 0., 0., 0., 0.]), '_r': array([False, False, False,  True, False, False, False, False]), 'l': array([ 0,  0,  0, 31,  0,  0,  0,  0]), '_l': array([False, False, False,  True, False, False, False, False]), 't': array([0.      , 0.      , 0.      , 0.010213, 0.      , 0.      ,
#        0.      , 0.      ]), '_t': array([False, False, False,  True, False, False, False, False])}, '_episode': array([False, False, False,  True, False, False, False, False])}
# {}
# {}
# {}
# {}
# {'episode': {'r': array([0., 0., 1., 0., 0., 0., 0., 0.]), '_r': array([False, False,  True, False, False, False, False, False]), 'l': array([0, 0, 5, 0, 0, 0, 0, 0]), '_l': array([False, False,  True, False, False, False, False, False]), 't': array([0.      , 0.      , 0.000988, 0.      , 0.      , 0.      ,
#        0.      , 0.      ]), '_t': array([False, False,  True, False, False, False, False, False])}, '_episode': array([False, False,  True, False, False, False, False, False])}
# {}
# {}
# {'episode': {'r': array([0., 0., 0., 0., 0., 0., 0., 0.]), '_r': array([False, False, False, False, False, False, False,  True]), 'l': array([ 0,  0,  0,  0,  0,  0,  0, 39]), '_l': array([False, False, False, False, False, False, False,  True]), 't': array([0.     , 0.     , 0.     , 0.     , 0.     , 0.     , 0.     ,
#        0.01141]), '_t': array([False, False, False, False, False, False, False,  True])}, '_episode': array([False, False, False, False, False, False, False,  True])}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'episode': {'r': array([0., 0., 0., 0., 0., 0., 0., 0.]), '_r': array([ True, False, False, False, False, False, False, False]), 'l': array([49,  0,  0,  0,  0,  0,  0,  0]), '_l': array([ True, False, False, False, False, False, False, False]), 't': array([0.014901, 0.      , 0.      , 0.      , 0.      , 0.      ,
#        0.      , 0.      ]), '_t': array([ True, False, False, False, False, False, False, False])}, '_episode': array([ True, False, False, False, False, False, False, False])}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'episode': {'r': array([0., 0., 0., 0., 0., 0., 0., 0.]), '_r': array([False,  True, False, False, False, False, False, False]), 'l': array([ 0, 66,  0,  0,  0,  0,  0,  0]), '_l': array([False,  True, False, False, False, False, False, False]), 't': array([0.     , 0.01685, 0.     , 0.     , 0.     , 0.     , 0.     ,
#        0.     ]), '_t': array([False,  True, False, False, False, False, False, False])}, '_episode': array([False,  True, False, False, False, False, False, False])}
# {}
# {'episode': {'r': array([0., 0., 0., 0., 0., 0., 0., 0.]), '_r': array([False, False, False, False,  True, False, False, False]), 'l': array([ 0,  0,  0,  0, 68,  0,  0,  0]), '_l': array([False, False, False, False,  True, False, False, False]), 't': array([0.      , 0.      , 0.      , 0.      , 0.015596, 0.      ,
#        0.      , 0.      ]), '_t': array([False, False, False, False,  True, False, False, False])}, '_episode': array([False, False, False, False,  True, False, False, False])}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'episode': {'r': array([0., 0., 1., 0., 0., 0., 0., 0.]), '_r': array([False, False,  True, False, False, False, False, False]), 'l': array([ 0,  0, 39,  0,  0,  0,  0,  0]), '_l': array([False, False,  True, False, False, False, False, False]), 't': array([0.      , 0.      , 0.005319, 0.      , 0.      , 0.      ,
#        0.      , 0.      ]), '_t': array([False, False,  True, False, False, False, False, False])}, '_episode': array([False, False,  True, False, False, False, False, False])}
# {}
# {}
# {'episode': {'r': array([0., 1., 0., 0., 0., 0., 0., 0.]), '_r': array([False,  True, False, False, False, False, False, False]), 'l': array([ 0, 12,  0,  0,  0,  0,  0,  0]), '_l': array([False,  True, False, False, False, False, False, False]), 't': array([0.      , 0.001882, 0.      , 0.      , 0.      , 0.      ,
#        0.      , 0.      ]), '_t': array([False,  True, False, False, False, False, False, False])}, '_episode': array([False,  True, False, False, False, False, False, False])}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'episode': {'r': array([0., 0., 0., 0., 0., 0., 0., 0.]), '_r': array([False, False, False,  True, False, False, False, False]), 'l': array([ 0,  0,  0, 60,  0,  0,  0,  0]), '_l': array([False, False, False,  True, False, False, False, False]), 't': array([0.      , 0.      , 0.      , 0.008416, 0.      , 0.      ,
#        0.      , 0.      ]), '_t': array([False, False, False,  True, False, False, False, False])}, '_episode': array([False, False, False,  True, False, False, False, False])}
# {'episode': {'r': array([0., 1., 0., 0., 0., 0., 0., 0.]), '_r': array([False,  True, False, False, False, False, False, False]), 'l': array([ 0, 13,  0,  0,  0,  0,  0,  0]), '_l': array([False,  True, False, False, False, False, False, False]), 't': array([0.      , 0.001812, 0.      , 0.      , 0.      , 0.      ,
#        0.      , 0.      ]), '_t': array([False,  True, False, False, False, False, False, False])}, '_episode': array([False,  True, False, False, False, False, False, False])}
# {}
# {}
# {}
# {}
# {}
# {}
# {}

# %%
obs.shape
# Out:
# (8, 4, 30, 30)

# %%
obs = torch.as_tensor(obs, dtype=torch.float32)
obs.shape
# Out:
# torch.Size([8, 4, 30, 30])

# %%
cnn = nn.Sequential(
    nn.Conv2d(stack_size, 32, 3, 1, 1),
    nn.ReLU(),
    nn.Conv2d(32, 64, 3, 2, 1),
    nn.ReLU(),
    nn.Conv2d(64, 64, 3, 2, 1),
    nn.ReLU(),
    
    nn.Flatten(),
    nn.Linear(64 * 8 * 8, 512),
    nn.ReLU(),  
)
print(cnn(obs).shape)
# Out:
# torch.Size([8, 512])

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer

class Agent(nn.Module):
    def __init__(self, n_hid, n_out):
        super().__init__()
        self.network = nn.Sequential(
            layer_init(nn.Conv2d(stack_size, 32, kernel_size=3, stride=1, padding=1)),
            nn.ReLU(),
            
            layer_init(nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)),
            nn.ReLU(),         
               
            layer_init(nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1)),
            nn.ReLU(),
            
            nn.Flatten(),
            layer_init(nn.Linear(64 * 8 * 8, n_hid)),
            nn.ReLU(),  
        )
        
        self.actor = layer_init(nn.Linear(n_hid, n_out), std=0.01)
        self.critic = layer_init(nn.Linear(n_hid, 1), std=1)                

    def get_value(self, x):
        return self.critic(self.network(x))

    def get_action_and_value(self, x, action=None):
        hidden = self.network(x)
        logits = self.actor(hidden)
        probs = torch.distributions.Categorical(logits=logits)
        if action is None:
            action = probs.sample()
        return action, probs.log_prob(action), probs.entropy(), self.critic(hidden)
    
def train(
    envs,
    model,
    optimizer,
    updates,
    update_epochs,
    num_steps,
    target_kl = 0.03,
    mini_batch_size = 64,
    gae_lambda = 0.95,
    clip_coef = 0.2,
    ent_coef = 0.01,
    vf_coef = 0.5,
    max_grad_norm = 0.5,
    norm_advantages = False,
    clip_vloss = False,
    lr_decay = False,
    gamma = 0.999,
    initial_lr = 1e-3,
    min_lr = 1e-5
):
    
    total_timesteps = updates * num_steps * num_envs
    
    writer = SummaryWriter(f"runs/snake-v12")
    
    batch_size = num_steps * num_envs
    
    obs = torch.zeros((num_steps, num_envs) + envs.single_observation_space.shape).to(device)
    actions = torch.zeros((num_steps, num_envs) + envs.single_action_space.shape, dtype=torch.long).to(device)
    logprobs = torch.zeros((num_steps, num_envs)).to(device)
    rewards = torch.zeros((num_steps, num_envs)).to(device)
    dones = torch.zeros((num_steps, num_envs)).to(device)
    values = torch.zeros((num_steps, num_envs)).to(device)
    
    global_step = 0
    next_obs, _ = envs.reset()
    next_obs = torch.Tensor(next_obs).to(device)
    next_done = torch.zeros(num_envs).to(device)
    start_time = time.time()
    
    for episode in range(1, updates + 1):      
        total_reward = 0
        
        if lr_decay:
            frac = max(
                0.0,
                1.0 - global_step / total_timesteps
            )

            lrnow = min_lr + frac * (initial_lr - min_lr)

            optimizer.param_groups[0]["lr"] = lrnow
        
        for step in range(0, num_steps):
            global_step += num_envs
            obs[step] = next_obs
            dones[step] = next_done
            
            with torch.no_grad():
                action, logprob, _, value = model.get_action_and_value(next_obs)
                values[step] = value.flatten()
            actions[step] = action
            logprobs[step] = logprob
            
            next_obs, reward, terminations, truncations, infos = envs.step(action.cpu().numpy())
            next_done = np.logical_or(terminations, truncations)
            rewards[step] = torch.tensor(reward).to(device).view(-1)
            total_reward += float(reward.mean())
            next_obs, next_done = torch.Tensor(next_obs).to(device), torch.tensor(next_done, dtype=torch.float32).to(device)
            
            if "episode" in infos:
                ep = infos["episode"]

                for reward, finished, length in zip(
                    ep["r"],
                    ep["_r"],
                    ep["l"],
                ):
                    if finished:
                        writer.add_scalar("charts/episodic_return", reward, global_step)
                        writer.add_scalar("charts/episodic_length", length, global_step)
                
                                    
        with torch.no_grad():
            next_value = model.get_value(next_obs).reshape(1, -1)
            advantages = torch.zeros_like(rewards).to(device)
            lastgaelam = 0
            for t in reversed(range(num_steps)):
                if t == num_steps - 1:
                    next_nonterminal = 1.0 - next_done
                    next_values = next_value
                else:
                    next_nonterminal = 1.0 - dones[t + 1]
                    next_values = values[t + 1]
                delta = rewards[t] + gamma * next_values * next_nonterminal - values[t]
                advantages[t] = lastgaelam = delta + gamma * gae_lambda * next_nonterminal * lastgaelam
            returns = advantages + values
         
        b_obs = obs.reshape((-1,) + envs.single_observation_space.shape)
        b_logprobs = logprobs.reshape(-1)
        b_actions = actions.reshape((-1,) + envs.single_action_space.shape)
        b_advanatages = advantages.reshape(-1)
        b_returns = returns.reshape(-1)
        b_values = values.reshape(-1)
        
        b_inds = np.arange(batch_size)
        clipfracs = []
        for epoch in range(update_epochs):
            np.random.shuffle(b_inds)
            for start in range(0, batch_size, mini_batch_size):
                end = start + mini_batch_size
                mb_inds = b_inds[start:end]
                
                _, newlogprob, entropy, newvalue = model.get_action_and_value(b_obs[mb_inds], b_actions.long()[mb_inds])
                logratio = newlogprob - b_logprobs[mb_inds]
                ratio = logratio.exp()
                
                with torch.no_grad():
                    old_approx_kl = (-logratio).mean()
                    approx_kl = ((ratio - 1) - logratio).mean()
                    clipfracs += [((ratio - 1.0).abs() > clip_coef).float().mean().item()]
                    
                mb_advantages = b_advanatages[mb_inds]
                if norm_advantages: 
                    mb_advantages = (mb_advantages-mb_advantages.mean()) / (mb_advantages.std() + 1e-8)
                
                pg_loss1 = -mb_advantages * ratio
                pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - clip_coef, 1 + clip_coef)
                pg_loss = torch.max(pg_loss1, pg_loss2).mean()
                
                new_value = newvalue.view(-1)

                if clip_vloss:
                    v_loss_unclipped = (
                        new_value - b_returns[mb_inds]
                    ) ** 2

                    v_clipped = (
                        b_values[mb_inds]
                        + torch.clamp(
                            new_value - b_values[mb_inds],
                            -clip_coef,
                            clip_coef,
                        )
                    )

                    v_loss_clipped = (
                        v_clipped - b_returns[mb_inds]
                    ) ** 2

                    v_loss_max = torch.max(
                        v_loss_unclipped,
                        v_loss_clipped
                    )

                    v_loss = 0.5 * v_loss_max.mean()

                else:
                    v_loss = 0.5 * (
                        (new_value - b_returns[mb_inds]) ** 2
                    ).mean()
                    
                entropy_loss = entropy.mean()
                loss = pg_loss - ent_coef * entropy_loss + v_loss * vf_coef
                
                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
                optimizer.step()
                
            if target_kl is not None and approx_kl > target_kl:
                break
            
        y_pred, y_true = b_values.cpu().numpy(), b_returns.cpu().numpy()
        var_y = np.var(y_true)
        explained_var = np.nan if var_y == 0 else 1 - np.var(y_true - y_pred) / var_y
        
        writer.add_scalar("charts/learning_rate", optimizer.param_groups[0]["lr"], global_step)
        writer.add_scalar("losses/value_loss", v_loss.item(), global_step)
        writer.add_scalar("losses/policy_loss", pg_loss.item(), global_step)
        writer.add_scalar("losses/entropy", entropy_loss.item(), global_step)
        writer.add_scalar("losses/old_approx_kl", old_approx_kl.item(), global_step)
        writer.add_scalar("losses/approx_kl", approx_kl.item(), global_step)
        writer.add_scalar("losses/clipfrac", np.mean(clipfracs), global_step)
        writer.add_scalar("losses/explained_variance", explained_var, global_step)
        writer.add_scalar("charts/mean_rollout_reward", total_reward, global_step) 
        print(f"\rSPS: {int(global_step / (time.time() - start_time))} | episode: {episode} | mean rollout reward: {total_reward} | global_step: {global_step}")
        writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)
            
    envs.close()
    writer.close()

# %%
lr = 1e-5
agent = Agent(512, action_size).to(device)
agent.load_state_dict(torch.load("../models/ppo/agent-v11.pth"))

optimizer = torch.optim.NAdam(agent.parameters(), lr=lr, eps=1e-5)
optimizer.load_state_dict(torch.load("../models/ppo/optimizer-v11.pth"))

for pg in optimizer.param_groups:
    pg["lr"] = lr
    print(f"current lr: {pg["lr"]}")
# Out:
# current lr: 1e-05

# %%
train(
    envs=envs,
    model=agent,
    optimizer=optimizer,
    updates=train_episodes,
    
    update_epochs=4,
    num_steps=num_steps,
    target_kl=0.03,
    mini_batch_size=512,
    gae_lambda=0.95,
    clip_coef=0.2,
    ent_coef=0.01,
    vf_coef=0.5,
    max_grad_norm=0.5,
    
    norm_advantages=True,
    clip_vloss=True,
    lr_decay=True,
    
    gamma=0.9999,
    initial_lr=lr,
    min_lr=7e-6
)
# Out:
# SPS: 2700 | episode: 1 | mean rollout reward: 47.5 | global_step: 16384
# SPS: 2549 | episode: 2 | mean rollout reward: 36.875 | global_step: 32768
# SPS: 2561 | episode: 3 | mean rollout reward: 28.5 | global_step: 49152
# SPS: 2600 | episode: 4 | mean rollout reward: 34.875 | global_step: 65536
# SPS: 2579 | episode: 5 | mean rollout reward: 28.875 | global_step: 81920
# SPS: 2502 | episode: 6 | mean rollout reward: 24.875 | global_step: 98304
# SPS: 2456 | episode: 7 | mean rollout reward: 31.375 | global_step: 114688
# SPS: 2444 | episode: 8 | mean rollout reward: 32.125 | global_step: 131072
# SPS: 2443 | episode: 9 | mean rollout reward: 27.0 | global_step: 147456
# SPS: 2431 | episode: 10 | mean rollout reward: 36.0 | global_step: 163840
# SPS: 2425 | episode: 11 | mean rollout reward: 31.5 | global_step: 180224
# SPS: 2426 | episode: 12 | mean rollout reward: 28.375 | global_step: 196608
# SPS: 2420 | episode: 13 | mean rollout reward: 29.75 | global_step: 212992
# SPS: 2414 | episode: 14 | mean rollout reward: 33.75 | global_step: 229376
# SPS: 2396 | episode: 15 | mean rollout reward: 29.875 | global_step: 245760
# SPS: 2396 | episode: 16 | mean rollout reward: 35.125 | global_step: 262144
# SPS: 2394 | episode: 17 | mean rollout reward: 33.625 | global_step: 278528
# SPS: 2259 | episode: 18 | mean rollout reward: 36.375 | global_step: 294912
# SPS: 2159 | episode: 19 | mean rollout reward: 29.75 | global_step: 311296
# SPS: 2166 | episode: 20 | mean rollout reward: 29.75 | global_step: 327680
# SPS: 2173 | episode: 21 | mean rollout reward: 27.75 | global_step: 344064
# SPS: 2179 | episode: 22 | mean rollout reward: 38.125 | global_step: 360448
# SPS: 2098 | episode: 23 | mean rollout reward: 31.625 | global_step: 376832
# SPS: 2026 | episode: 24 | mean rollout reward: 33.25 | global_step: 393216
# SPS: 2032 | episode: 25 | mean rollout reward: 39.5 | global_step: 409600
# SPS: 2041 | episode: 26 | mean rollout reward: 39.0 | global_step: 425984
# SPS: 2047 | episode: 27 | mean rollout reward: 29.375 | global_step: 442368
# SPS: 2028 | episode: 28 | mean rollout reward: 31.875 | global_step: 458752
# SPS: 2032 | episode: 29 | mean rollout reward: 37.625 | global_step: 475136
# SPS: 2032 | episode: 30 | mean rollout reward: 37.25 | global_step: 491520
# SPS: 2037 | episode: 31 | mean rollout reward: 32.875 | global_step: 507904
# SPS: 2046 | episode: 32 | mean rollout reward: 29.25 | global_step: 524288
# SPS: 2053 | episode: 33 | mean rollout reward: 29.875 | global_step: 540672
# SPS: 2061 | episode: 34 | mean rollout reward: 32.75 | global_step: 557056
# SPS: 2066 | episode: 35 | mean rollout reward: 28.375 | global_step: 573440
# SPS: 2068 | episode: 36 | mean rollout reward: 32.5 | global_step: 589824
# SPS: 2073 | episode: 37 | mean rollout reward: 35.5 | global_step: 606208
# SPS: 2078 | episode: 38 | mean rollout reward: 33.5 | global_step: 622592
# SPS: 2081 | episode: 39 | mean rollout reward: 33.375 | global_step: 638976
# SPS: 2085 | episode: 40 | mean rollout reward: 34.5 | global_step: 655360
# SPS: 2090 | episode: 41 | mean rollout reward: 32.75 | global_step: 671744
# SPS: 2094 | episode: 42 | mean rollout reward: 32.625 | global_step: 688128
# SPS: 2098 | episode: 43 | mean rollout reward: 33.75 | global_step: 704512
# SPS: 2101 | episode: 44 | mean rollout reward: 31.5 | global_step: 720896
# SPS: 2104 | episode: 45 | mean rollout reward: 30.0 | global_step: 737280
# SPS: 2107 | episode: 46 | mean rollout reward: 28.0 | global_step: 753664
# SPS: 2110 | episode: 47 | mean rollout reward: 32.75 | global_step: 770048
# SPS: 2113 | episode: 48 | mean rollout reward: 33.25 | global_step: 786432
# SPS: 2117 | episode: 49 | mean rollout reward: 29.875 | global_step: 802816
# SPS: 2119 | episode: 50 | mean rollout reward: 26.625 | global_step: 819200
# SPS: 2121 | episode: 51 | mean rollout reward: 29.375 | global_step: 835584
# SPS: 2123 | episode: 52 | mean rollout reward: 28.25 | global_step: 851968
# SPS: 2125 | episode: 53 | mean rollout reward: 34.75 | global_step: 868352
# SPS: 2128 | episode: 54 | mean rollout reward: 38.875 | global_step: 884736
# SPS: 2130 | episode: 55 | mean rollout reward: 30.5 | global_step: 901120
# SPS: 2133 | episode: 56 | mean rollout reward: 29.375 | global_step: 917504
# SPS: 2136 | episode: 57 | mean rollout reward: 27.0 | global_step: 933888
# SPS: 2138 | episode: 58 | mean rollout reward: 31.25 | global_step: 950272
# SPS: 2140 | episode: 59 | mean rollout reward: 33.375 | global_step: 966656
# SPS: 2142 | episode: 60 | mean rollout reward: 35.125 | global_step: 983040
# SPS: 2144 | episode: 61 | mean rollout reward: 29.375 | global_step: 999424
# SPS: 2146 | episode: 62 | mean rollout reward: 33.125 | global_step: 1015808
# SPS: 2148 | episode: 63 | mean rollout reward: 29.25 | global_step: 1032192
# SPS: 2150 | episode: 64 | mean rollout reward: 36.25 | global_step: 1048576
# SPS: 2150 | episode: 65 | mean rollout reward: 35.875 | global_step: 1064960
# SPS: 2151 | episode: 66 | mean rollout reward: 32.625 | global_step: 1081344
# SPS: 2152 | episode: 67 | mean rollout reward: 29.875 | global_step: 1097728
# SPS: 2155 | episode: 68 | mean rollout reward: 36.125 | global_step: 1114112
# SPS: 2157 | episode: 69 | mean rollout reward: 28.75 | global_step: 1130496
# SPS: 2158 | episode: 70 | mean rollout reward: 26.375 | global_step: 1146880
# SPS: 2157 | episode: 71 | mean rollout reward: 27.25 | global_step: 1163264
# SPS: 2158 | episode: 72 | mean rollout reward: 29.375 | global_step: 1179648
# SPS: 2158 | episode: 73 | mean rollout reward: 27.75 | global_step: 1196032
# SPS: 2160 | episode: 74 | mean rollout reward: 31.25 | global_step: 1212416
# SPS: 2159 | episode: 75 | mean rollout reward: 26.0 | global_step: 1228800
# SPS: 2161 | episode: 76 | mean rollout reward: 27.375 | global_step: 1245184
# SPS: 2162 | episode: 77 | mean rollout reward: 27.25 | global_step: 1261568
# SPS: 2163 | episode: 78 | mean rollout reward: 26.375 | global_step: 1277952
# SPS: 2162 | episode: 79 | mean rollout reward: 22.5 | global_step: 1294336
# SPS: 2163 | episode: 80 | mean rollout reward: 29.75 | global_step: 1310720
# SPS: 2163 | episode: 81 | mean rollout reward: 36.125 | global_step: 1327104
# SPS: 2162 | episode: 82 | mean rollout reward: 33.875 | global_step: 1343488
# SPS: 2164 | episode: 83 | mean rollout reward: 31.0 | global_step: 1359872
# SPS: 2164 | episode: 84 | mean rollout reward: 33.375 | global_step: 1376256
# SPS: 2162 | episode: 85 | mean rollout reward: 34.125 | global_step: 1392640
# SPS: 2164 | episode: 86 | mean rollout reward: 31.5 | global_step: 1409024
# SPS: 2165 | episode: 87 | mean rollout reward: 32.375 | global_step: 1425408
# SPS: 2166 | episode: 88 | mean rollout reward: 34.375 | global_step: 1441792
# SPS: 2166 | episode: 89 | mean rollout reward: 27.75 | global_step: 1458176
# SPS: 2167 | episode: 90 | mean rollout reward: 27.625 | global_step: 1474560
# SPS: 2167 | episode: 91 | mean rollout reward: 30.25 | global_step: 1490944
# SPS: 2169 | episode: 92 | mean rollout reward: 32.875 | global_step: 1507328
# SPS: 2169 | episode: 93 | mean rollout reward: 34.875 | global_step: 1523712
# SPS: 2170 | episode: 94 | mean rollout reward: 28.125 | global_step: 1540096
# SPS: 2171 | episode: 95 | mean rollout reward: 29.0 | global_step: 1556480
# SPS: 2171 | episode: 96 | mean rollout reward: 27.125 | global_step: 1572864
# SPS: 2170 | episode: 97 | mean rollout reward: 24.375 | global_step: 1589248
# SPS: 2171 | episode: 98 | mean rollout reward: 28.875 | global_step: 1605632
# SPS: 2170 | episode: 99 | mean rollout reward: 32.625 | global_step: 1622016
# SPS: 2171 | episode: 100 | mean rollout reward: 25.625 | global_step: 1638400
# SPS: 2171 | episode: 101 | mean rollout reward: 29.625 | global_step: 1654784
# SPS: 2172 | episode: 102 | mean rollout reward: 27.25 | global_step: 1671168
# SPS: 2172 | episode: 103 | mean rollout reward: 29.0 | global_step: 1687552
# SPS: 2173 | episode: 104 | mean rollout reward: 25.25 | global_step: 1703936
# SPS: 2173 | episode: 105 | mean rollout reward: 27.25 | global_step: 1720320
# SPS: 2173 | episode: 106 | mean rollout reward: 29.25 | global_step: 1736704
# SPS: 2172 | episode: 107 | mean rollout reward: 30.25 | global_step: 1753088
# SPS: 2173 | episode: 108 | mean rollout reward: 34.5 | global_step: 1769472
# SPS: 2173 | episode: 109 | mean rollout reward: 35.375 | global_step: 1785856
# SPS: 2174 | episode: 110 | mean rollout reward: 35.25 | global_step: 1802240
# SPS: 2174 | episode: 111 | mean rollout reward: 35.25 | global_step: 1818624
# SPS: 2175 | episode: 112 | mean rollout reward: 31.625 | global_step: 1835008
# SPS: 2174 | episode: 113 | mean rollout reward: 29.375 | global_step: 1851392
# SPS: 2174 | episode: 114 | mean rollout reward: 31.5 | global_step: 1867776
# SPS: 2173 | episode: 115 | mean rollout reward: 31.5 | global_step: 1884160
# SPS: 2174 | episode: 116 | mean rollout reward: 28.75 | global_step: 1900544
# SPS: 2174 | episode: 117 | mean rollout reward: 28.75 | global_step: 1916928
# SPS: 2174 | episode: 118 | mean rollout reward: 30.25 | global_step: 1933312
# SPS: 2174 | episode: 119 | mean rollout reward: 36.125 | global_step: 1949696
# SPS: 2175 | episode: 120 | mean rollout reward: 34.875 | global_step: 1966080
# SPS: 2174 | episode: 121 | mean rollout reward: 29.25 | global_step: 1982464
# SPS: 2173 | episode: 122 | mean rollout reward: 34.625 | global_step: 1998848
# SPS: 2173 | episode: 123 | mean rollout reward: 34.875 | global_step: 2015232
# SPS: 2172 | episode: 124 | mean rollout reward: 33.25 | global_step: 2031616
# SPS: 2171 | episode: 125 | mean rollout reward: 32.875 | global_step: 2048000
# SPS: 2171 | episode: 126 | mean rollout reward: 32.0 | global_step: 2064384
# SPS: 2171 | episode: 127 | mean rollout reward: 29.125 | global_step: 2080768
# SPS: 2172 | episode: 128 | mean rollout reward: 28.0 | global_step: 2097152
# SPS: 2170 | episode: 129 | mean rollout reward: 33.625 | global_step: 2113536
# SPS: 2171 | episode: 130 | mean rollout reward: 38.375 | global_step: 2129920
# SPS: 2170 | episode: 131 | mean rollout reward: 32.0 | global_step: 2146304
# SPS: 2171 | episode: 132 | mean rollout reward: 36.375 | global_step: 2162688
# SPS: 2171 | episode: 133 | mean rollout reward: 32.0 | global_step: 2179072
# SPS: 2171 | episode: 134 | mean rollout reward: 32.0 | global_step: 2195456
# SPS: 2169 | episode: 135 | mean rollout reward: 25.625 | global_step: 2211840
# SPS: 2170 | episode: 136 | mean rollout reward: 33.0 | global_step: 2228224
# SPS: 2170 | episode: 137 | mean rollout reward: 37.5 | global_step: 2244608
# SPS: 2170 | episode: 138 | mean rollout reward: 28.375 | global_step: 2260992
# SPS: 2170 | episode: 139 | mean rollout reward: 29.625 | global_step: 2277376
# SPS: 2169 | episode: 140 | mean rollout reward: 35.375 | global_step: 2293760
# SPS: 2169 | episode: 141 | mean rollout reward: 26.875 | global_step: 2310144
# SPS: 2169 | episode: 142 | mean rollout reward: 23.5 | global_step: 2326528
# SPS: 2170 | episode: 143 | mean rollout reward: 29.25 | global_step: 2342912
# SPS: 2171 | episode: 144 | mean rollout reward: 26.5 | global_step: 2359296
# SPS: 2170 | episode: 145 | mean rollout reward: 28.5 | global_step: 2375680
# SPS: 2170 | episode: 146 | mean rollout reward: 27.0 | global_step: 2392064
# SPS: 2170 | episode: 147 | mean rollout reward: 31.0 | global_step: 2408448
# SPS: 2172 | episode: 148 | mean rollout reward: 30.75 | global_step: 2424832
# SPS: 2171 | episode: 149 | mean rollout reward: 29.25 | global_step: 2441216
# SPS: 2171 | episode: 150 | mean rollout reward: 31.125 | global_step: 2457600
# SPS: 2171 | episode: 151 | mean rollout reward: 32.875 | global_step: 2473984
# SPS: 2172 | episode: 152 | mean rollout reward: 32.625 | global_step: 2490368
# SPS: 2172 | episode: 153 | mean rollout reward: 30.125 | global_step: 2506752
# SPS: 2173 | episode: 154 | mean rollout reward: 30.125 | global_step: 2523136
# SPS: 2173 | episode: 155 | mean rollout reward: 31.625 | global_step: 2539520
# SPS: 2173 | episode: 156 | mean rollout reward: 25.875 | global_step: 2555904
# SPS: 2173 | episode: 157 | mean rollout reward: 27.75 | global_step: 2572288
# SPS: 2173 | episode: 158 | mean rollout reward: 33.5 | global_step: 2588672
# SPS: 2173 | episode: 159 | mean rollout reward: 35.75 | global_step: 2605056
# SPS: 2174 | episode: 160 | mean rollout reward: 28.5 | global_step: 2621440
# SPS: 2173 | episode: 161 | mean rollout reward: 25.625 | global_step: 2637824
# SPS: 2174 | episode: 162 | mean rollout reward: 31.375 | global_step: 2654208
# SPS: 2174 | episode: 163 | mean rollout reward: 30.75 | global_step: 2670592
# SPS: 2174 | episode: 164 | mean rollout reward: 33.875 | global_step: 2686976
# SPS: 2174 | episode: 165 | mean rollout reward: 28.875 | global_step: 2703360
# SPS: 2175 | episode: 166 | mean rollout reward: 24.125 | global_step: 2719744
# SPS: 2176 | episode: 167 | mean rollout reward: 25.875 | global_step: 2736128
# SPS: 2176 | episode: 168 | mean rollout reward: 31.625 | global_step: 2752512
# SPS: 2176 | episode: 169 | mean rollout reward: 29.25 | global_step: 2768896
# SPS: 2177 | episode: 170 | mean rollout reward: 24.75 | global_step: 2785280
# SPS: 2177 | episode: 171 | mean rollout reward: 22.5 | global_step: 2801664
# SPS: 2177 | episode: 172 | mean rollout reward: 24.75 | global_step: 2818048
# SPS: 2177 | episode: 173 | mean rollout reward: 35.375 | global_step: 2834432
# SPS: 2177 | episode: 174 | mean rollout reward: 40.875 | global_step: 2850816
# SPS: 2177 | episode: 175 | mean rollout reward: 35.625 | global_step: 2867200
# SPS: 2177 | episode: 176 | mean rollout reward: 35.625 | global_step: 2883584
# SPS: 2177 | episode: 177 | mean rollout reward: 25.75 | global_step: 2899968
# SPS: 2178 | episode: 178 | mean rollout reward: 27.5 | global_step: 2916352
# SPS: 2177 | episode: 179 | mean rollout reward: 32.5 | global_step: 2932736
# SPS: 2178 | episode: 180 | mean rollout reward: 31.0 | global_step: 2949120
# SPS: 2177 | episode: 181 | mean rollout reward: 29.25 | global_step: 2965504
# SPS: 2177 | episode: 182 | mean rollout reward: 22.875 | global_step: 2981888
# SPS: 2177 | episode: 183 | mean rollout reward: 25.375 | global_step: 2998272
# SPS: 2177 | episode: 184 | mean rollout reward: 30.875 | global_step: 3014656
# SPS: 2177 | episode: 185 | mean rollout reward: 28.25 | global_step: 3031040
# SPS: 2177 | episode: 186 | mean rollout reward: 32.0 | global_step: 3047424
# SPS: 2177 | episode: 187 | mean rollout reward: 34.625 | global_step: 3063808
# SPS: 2175 | episode: 188 | mean rollout reward: 25.0 | global_step: 3080192
# SPS: 2175 | episode: 189 | mean rollout reward: 26.375 | global_step: 3096576
# SPS: 2176 | episode: 190 | mean rollout reward: 26.375 | global_step: 3112960
# SPS: 2176 | episode: 191 | mean rollout reward: 31.875 | global_step: 3129344
# SPS: 2175 | episode: 192 | mean rollout reward: 29.625 | global_step: 3145728
# SPS: 2175 | episode: 193 | mean rollout reward: 30.125 | global_step: 3162112
# SPS: 2174 | episode: 194 | mean rollout reward: 24.125 | global_step: 3178496
# SPS: 2174 | episode: 195 | mean rollout reward: 29.25 | global_step: 3194880
# SPS: 2174 | episode: 196 | mean rollout reward: 24.375 | global_step: 3211264
# SPS: 2174 | episode: 197 | mean rollout reward: 28.875 | global_step: 3227648
# SPS: 2174 | episode: 198 | mean rollout reward: 25.5 | global_step: 3244032
# SPS: 2162 | episode: 199 | mean rollout reward: 27.125 | global_step: 3260416
# SPS: 2154 | episode: 200 | mean rollout reward: 29.0 | global_step: 3276800
# SPS: 2154 | episode: 201 | mean rollout reward: 33.5 | global_step: 3293184
# SPS: 2154 | episode: 202 | mean rollout reward: 32.75 | global_step: 3309568
# SPS: 2154 | episode: 203 | mean rollout reward: 29.5 | global_step: 3325952
# SPS: 2154 | episode: 204 | mean rollout reward: 23.375 | global_step: 3342336
# SPS: 2154 | episode: 205 | mean rollout reward: 22.5 | global_step: 3358720
# SPS: 2154 | episode: 206 | mean rollout reward: 22.625 | global_step: 3375104
# SPS: 2154 | episode: 207 | mean rollout reward: 28.625 | global_step: 3391488
# SPS: 2154 | episode: 208 | mean rollout reward: 35.5 | global_step: 3407872
# SPS: 2155 | episode: 209 | mean rollout reward: 29.0 | global_step: 3424256
# SPS: 2155 | episode: 210 | mean rollout reward: 24.0 | global_step: 3440640
# SPS: 2155 | episode: 211 | mean rollout reward: 24.625 | global_step: 3457024
# SPS: 2155 | episode: 212 | mean rollout reward: 26.5 | global_step: 3473408
# SPS: 2156 | episode: 213 | mean rollout reward: 32.5 | global_step: 3489792
# SPS: 2156 | episode: 214 | mean rollout reward: 32.5 | global_step: 3506176
# SPS: 2156 | episode: 215 | mean rollout reward: 29.875 | global_step: 3522560
# SPS: 2157 | episode: 216 | mean rollout reward: 33.25 | global_step: 3538944
# SPS: 2157 | episode: 217 | mean rollout reward: 35.125 | global_step: 3555328
# SPS: 2158 | episode: 218 | mean rollout reward: 26.875 | global_step: 3571712
# SPS: 2157 | episode: 219 | mean rollout reward: 22.375 | global_step: 3588096
# SPS: 2158 | episode: 220 | mean rollout reward: 26.625 | global_step: 3604480
# SPS: 2158 | episode: 221 | mean rollout reward: 28.125 | global_step: 3620864
# SPS: 2158 | episode: 222 | mean rollout reward: 24.5 | global_step: 3637248
# SPS: 2158 | episode: 223 | mean rollout reward: 27.75 | global_step: 3653632
# SPS: 2158 | episode: 224 | mean rollout reward: 29.125 | global_step: 3670016
# SPS: 2158 | episode: 225 | mean rollout reward: 31.75 | global_step: 3686400
# SPS: 2159 | episode: 226 | mean rollout reward: 32.125 | global_step: 3702784
# SPS: 2159 | episode: 227 | mean rollout reward: 21.875 | global_step: 3719168
# SPS: 2159 | episode: 228 | mean rollout reward: 22.0 | global_step: 3735552
# SPS: 2160 | episode: 229 | mean rollout reward: 30.125 | global_step: 3751936
# SPS: 2160 | episode: 230 | mean rollout reward: 32.875 | global_step: 3768320
# SPS: 2161 | episode: 231 | mean rollout reward: 36.75 | global_step: 3784704
# SPS: 2161 | episode: 232 | mean rollout reward: 29.875 | global_step: 3801088
# SPS: 2161 | episode: 233 | mean rollout reward: 34.75 | global_step: 3817472
# SPS: 2162 | episode: 234 | mean rollout reward: 28.375 | global_step: 3833856
# SPS: 2162 | episode: 235 | mean rollout reward: 33.0 | global_step: 3850240
# SPS: 2163 | episode: 236 | mean rollout reward: 40.75 | global_step: 3866624
# SPS: 2163 | episode: 237 | mean rollout reward: 29.75 | global_step: 3883008
# SPS: 2164 | episode: 238 | mean rollout reward: 26.875 | global_step: 3899392
# SPS: 2164 | episode: 239 | mean rollout reward: 26.625 | global_step: 3915776
# SPS: 2164 | episode: 240 | mean rollout reward: 24.5 | global_step: 3932160
# SPS: 2164 | episode: 241 | mean rollout reward: 24.75 | global_step: 3948544
# SPS: 2164 | episode: 242 | mean rollout reward: 29.625 | global_step: 3964928
# SPS: 2162 | episode: 243 | mean rollout reward: 28.375 | global_step: 3981312
# SPS: 2163 | episode: 244 | mean rollout reward: 33.625 | global_step: 3997696
# SPS: 2163 | episode: 245 | mean rollout reward: 26.5 | global_step: 4014080
# SPS: 2163 | episode: 246 | mean rollout reward: 22.875 | global_step: 4030464
# SPS: 2163 | episode: 247 | mean rollout reward: 27.5 | global_step: 4046848
# SPS: 2164 | episode: 248 | mean rollout reward: 39.125 | global_step: 4063232
# SPS: 2164 | episode: 249 | mean rollout reward: 32.25 | global_step: 4079616
# SPS: 2165 | episode: 250 | mean rollout reward: 25.875 | global_step: 4096000
# SPS: 2165 | episode: 251 | mean rollout reward: 30.0 | global_step: 4112384
# SPS: 2165 | episode: 252 | mean rollout reward: 29.875 | global_step: 4128768
# SPS: 2166 | episode: 253 | mean rollout reward: 26.625 | global_step: 4145152
# SPS: 2166 | episode: 254 | mean rollout reward: 25.5 | global_step: 4161536
# SPS: 2167 | episode: 255 | mean rollout reward: 22.75 | global_step: 4177920
# SPS: 2167 | episode: 256 | mean rollout reward: 30.125 | global_step: 4194304
# SPS: 2167 | episode: 257 | mean rollout reward: 31.0 | global_step: 4210688
# SPS: 2168 | episode: 258 | mean rollout reward: 29.0 | global_step: 4227072
# SPS: 2168 | episode: 259 | mean rollout reward: 24.5 | global_step: 4243456
# SPS: 2168 | episode: 260 | mean rollout reward: 28.625 | global_step: 4259840
# SPS: 2169 | episode: 261 | mean rollout reward: 28.5 | global_step: 4276224
# SPS: 2169 | episode: 262 | mean rollout reward: 28.875 | global_step: 4292608
# SPS: 2169 | episode: 263 | mean rollout reward: 25.5 | global_step: 4308992
# SPS: 2169 | episode: 264 | mean rollout reward: 22.625 | global_step: 4325376
# SPS: 2169 | episode: 265 | mean rollout reward: 25.75 | global_step: 4341760
# SPS: 2169 | episode: 266 | mean rollout reward: 32.375 | global_step: 4358144
# SPS: 2170 | episode: 267 | mean rollout reward: 39.375 | global_step: 4374528
# SPS: 2170 | episode: 268 | mean rollout reward: 31.0 | global_step: 4390912
# SPS: 2170 | episode: 269 | mean rollout reward: 41.875 | global_step: 4407296
# SPS: 2170 | episode: 270 | mean rollout reward: 33.125 | global_step: 4423680
# SPS: 2170 | episode: 271 | mean rollout reward: 25.875 | global_step: 4440064
# SPS: 2170 | episode: 272 | mean rollout reward: 33.25 | global_step: 4456448
# SPS: 2170 | episode: 273 | mean rollout reward: 32.125 | global_step: 4472832
# SPS: 2171 | episode: 274 | mean rollout reward: 30.75 | global_step: 4489216
# SPS: 2171 | episode: 275 | mean rollout reward: 29.75 | global_step: 4505600
# SPS: 2171 | episode: 276 | mean rollout reward: 26.625 | global_step: 4521984
# SPS: 2172 | episode: 277 | mean rollout reward: 27.75 | global_step: 4538368
# SPS: 2172 | episode: 278 | mean rollout reward: 24.25 | global_step: 4554752
# SPS: 2172 | episode: 279 | mean rollout reward: 25.875 | global_step: 4571136
# SPS: 2172 | episode: 280 | mean rollout reward: 30.125 | global_step: 4587520
# SPS: 2172 | episode: 281 | mean rollout reward: 28.125 | global_step: 4603904
# SPS: 2173 | episode: 282 | mean rollout reward: 32.125 | global_step: 4620288
# SPS: 2173 | episode: 283 | mean rollout reward: 24.625 | global_step: 4636672
# SPS: 2173 | episode: 284 | mean rollout reward: 30.5 | global_step: 4653056
# SPS: 2173 | episode: 285 | mean rollout reward: 35.875 | global_step: 4669440
# SPS: 2173 | episode: 286 | mean rollout reward: 26.375 | global_step: 4685824
# SPS: 2174 | episode: 287 | mean rollout reward: 28.125 | global_step: 4702208
# SPS: 2174 | episode: 288 | mean rollout reward: 26.125 | global_step: 4718592
# SPS: 2174 | episode: 289 | mean rollout reward: 29.75 | global_step: 4734976
# SPS: 2174 | episode: 290 | mean rollout reward: 31.75 | global_step: 4751360
# SPS: 2175 | episode: 291 | mean rollout reward: 26.375 | global_step: 4767744
# SPS: 2175 | episode: 292 | mean rollout reward: 30.625 | global_step: 4784128
# SPS: 2175 | episode: 293 | mean rollout reward: 35.25 | global_step: 4800512
# SPS: 2175 | episode: 294 | mean rollout reward: 31.75 | global_step: 4816896
# SPS: 2175 | episode: 295 | mean rollout reward: 30.125 | global_step: 4833280
# SPS: 2175 | episode: 296 | mean rollout reward: 29.75 | global_step: 4849664
# SPS: 2175 | episode: 297 | mean rollout reward: 24.75 | global_step: 4866048
# SPS: 2176 | episode: 298 | mean rollout reward: 27.5 | global_step: 4882432
# SPS: 2176 | episode: 299 | mean rollout reward: 27.625 | global_step: 4898816
# SPS: 2176 | episode: 300 | mean rollout reward: 22.375 | global_step: 4915200
# SPS: 2175 | episode: 301 | mean rollout reward: 30.375 | global_step: 4931584
# SPS: 2176 | episode: 302 | mean rollout reward: 33.875 | global_step: 4947968
# SPS: 2176 | episode: 303 | mean rollout reward: 27.0 | global_step: 4964352
# SPS: 2176 | episode: 304 | mean rollout reward: 29.875 | global_step: 4980736
# SPS: 2176 | episode: 305 | mean rollout reward: 25.5 | global_step: 4997120
# SPS: 2176 | episode: 306 | mean rollout reward: 26.5 | global_step: 5013504
# SPS: 2177 | episode: 307 | mean rollout reward: 29.0 | global_step: 5029888
# SPS: 2177 | episode: 308 | mean rollout reward: 31.125 | global_step: 5046272
# SPS: 2177 | episode: 309 | mean rollout reward: 29.625 | global_step: 5062656
# SPS: 2177 | episode: 310 | mean rollout reward: 28.125 | global_step: 5079040
# SPS: 2178 | episode: 311 | mean rollout reward: 28.75 | global_step: 5095424
# SPS: 2178 | episode: 312 | mean rollout reward: 35.875 | global_step: 5111808
# SPS: 2178 | episode: 313 | mean rollout reward: 34.625 | global_step: 5128192
# SPS: 2178 | episode: 314 | mean rollout reward: 26.75 | global_step: 5144576
# SPS: 2179 | episode: 315 | mean rollout reward: 22.0 | global_step: 5160960
# SPS: 2179 | episode: 316 | mean rollout reward: 31.25 | global_step: 5177344
# SPS: 2179 | episode: 317 | mean rollout reward: 39.125 | global_step: 5193728
# SPS: 2179 | episode: 318 | mean rollout reward: 32.25 | global_step: 5210112
# SPS: 2179 | episode: 319 | mean rollout reward: 22.25 | global_step: 5226496
# SPS: 2179 | episode: 320 | mean rollout reward: 23.75 | global_step: 5242880
# SPS: 2179 | episode: 321 | mean rollout reward: 25.75 | global_step: 5259264
# SPS: 2180 | episode: 322 | mean rollout reward: 34.625 | global_step: 5275648
# SPS: 2180 | episode: 323 | mean rollout reward: 37.25 | global_step: 5292032
# SPS: 2180 | episode: 324 | mean rollout reward: 27.125 | global_step: 5308416
# SPS: 2180 | episode: 325 | mean rollout reward: 22.625 | global_step: 5324800
# SPS: 2180 | episode: 326 | mean rollout reward: 29.0 | global_step: 5341184
# SPS: 2180 | episode: 327 | mean rollout reward: 33.0 | global_step: 5357568
# SPS: 2181 | episode: 328 | mean rollout reward: 29.375 | global_step: 5373952
# SPS: 2181 | episode: 329 | mean rollout reward: 31.0 | global_step: 5390336
# SPS: 2181 | episode: 330 | mean rollout reward: 28.0 | global_step: 5406720
# SPS: 2181 | episode: 331 | mean rollout reward: 29.25 | global_step: 5423104
# SPS: 2181 | episode: 332 | mean rollout reward: 33.75 | global_step: 5439488
# SPS: 2181 | episode: 333 | mean rollout reward: 32.0 | global_step: 5455872
# SPS: 2181 | episode: 334 | mean rollout reward: 34.875 | global_step: 5472256
# SPS: 2181 | episode: 335 | mean rollout reward: 31.625 | global_step: 5488640
# SPS: 2182 | episode: 336 | mean rollout reward: 35.75 | global_step: 5505024
# SPS: 2182 | episode: 337 | mean rollout reward: 28.875 | global_step: 5521408
# SPS: 2182 | episode: 338 | mean rollout reward: 29.75 | global_step: 5537792
# SPS: 2182 | episode: 339 | mean rollout reward: 27.75 | global_step: 5554176
# SPS: 2182 | episode: 340 | mean rollout reward: 30.625 | global_step: 5570560
# SPS: 2182 | episode: 341 | mean rollout reward: 28.375 | global_step: 5586944
# SPS: 2183 | episode: 342 | mean rollout reward: 26.0 | global_step: 5603328
# SPS: 2183 | episode: 343 | mean rollout reward: 26.375 | global_step: 5619712
# SPS: 2183 | episode: 344 | mean rollout reward: 27.0 | global_step: 5636096
# SPS: 2183 | episode: 345 | mean rollout reward: 27.125 | global_step: 5652480
# SPS: 2183 | episode: 346 | mean rollout reward: 34.75 | global_step: 5668864
# SPS: 2184 | episode: 347 | mean rollout reward: 36.125 | global_step: 5685248
# SPS: 2184 | episode: 348 | mean rollout reward: 25.0 | global_step: 5701632
# SPS: 2184 | episode: 349 | mean rollout reward: 23.25 | global_step: 5718016
# SPS: 2184 | episode: 350 | mean rollout reward: 30.25 | global_step: 5734400
# SPS: 2184 | episode: 351 | mean rollout reward: 34.0 | global_step: 5750784
# SPS: 2185 | episode: 352 | mean rollout reward: 33.875 | global_step: 5767168
# SPS: 2185 | episode: 353 | mean rollout reward: 34.75 | global_step: 5783552
# SPS: 2184 | episode: 354 | mean rollout reward: 27.125 | global_step: 5799936
# SPS: 2184 | episode: 355 | mean rollout reward: 26.5 | global_step: 5816320
# SPS: 2184 | episode: 356 | mean rollout reward: 29.375 | global_step: 5832704
# SPS: 2185 | episode: 357 | mean rollout reward: 34.625 | global_step: 5849088
# SPS: 2185 | episode: 358 | mean rollout reward: 31.25 | global_step: 5865472
# SPS: 2185 | episode: 359 | mean rollout reward: 32.875 | global_step: 5881856
# SPS: 2186 | episode: 360 | mean rollout reward: 32.0 | global_step: 5898240
# SPS: 2186 | episode: 361 | mean rollout reward: 29.0 | global_step: 5914624
# SPS: 2186 | episode: 362 | mean rollout reward: 34.625 | global_step: 5931008
# SPS: 2186 | episode: 363 | mean rollout reward: 31.625 | global_step: 5947392
# SPS: 2186 | episode: 364 | mean rollout reward: 34.0 | global_step: 5963776
# SPS: 2187 | episode: 365 | mean rollout reward: 34.625 | global_step: 5980160
# SPS: 2186 | episode: 366 | mean rollout reward: 27.375 | global_step: 5996544
# SPS: 2186 | episode: 367 | mean rollout reward: 26.375 | global_step: 6012928
# SPS: 2186 | episode: 368 | mean rollout reward: 34.75 | global_step: 6029312
# SPS: 2187 | episode: 369 | mean rollout reward: 37.125 | global_step: 6045696
# SPS: 2187 | episode: 370 | mean rollout reward: 34.125 | global_step: 6062080
# SPS: 2187 | episode: 371 | mean rollout reward: 33.875 | global_step: 6078464
# SPS: 2187 | episode: 372 | mean rollout reward: 27.125 | global_step: 6094848
# SPS: 2187 | episode: 373 | mean rollout reward: 26.125 | global_step: 6111232
# SPS: 2187 | episode: 374 | mean rollout reward: 27.5 | global_step: 6127616
# SPS: 2187 | episode: 375 | mean rollout reward: 26.375 | global_step: 6144000
# SPS: 2187 | episode: 376 | mean rollout reward: 27.375 | global_step: 6160384
# SPS: 2187 | episode: 377 | mean rollout reward: 30.0 | global_step: 6176768
# SPS: 2187 | episode: 378 | mean rollout reward: 33.625 | global_step: 6193152
# SPS: 2187 | episode: 379 | mean rollout reward: 28.875 | global_step: 6209536
# SPS: 2186 | episode: 380 | mean rollout reward: 27.25 | global_step: 6225920
# SPS: 2186 | episode: 381 | mean rollout reward: 29.375 | global_step: 6242304
# SPS: 2185 | episode: 382 | mean rollout reward: 27.0 | global_step: 6258688
# SPS: 2185 | episode: 383 | mean rollout reward: 33.875 | global_step: 6275072
# SPS: 2184 | episode: 384 | mean rollout reward: 32.125 | global_step: 6291456
# SPS: 2184 | episode: 385 | mean rollout reward: 26.625 | global_step: 6307840
# SPS: 2183 | episode: 386 | mean rollout reward: 26.625 | global_step: 6324224
# SPS: 2183 | episode: 387 | mean rollout reward: 29.875 | global_step: 6340608
# SPS: 2182 | episode: 388 | mean rollout reward: 34.375 | global_step: 6356992
# SPS: 2181 | episode: 389 | mean rollout reward: 35.375 | global_step: 6373376
# SPS: 2180 | episode: 390 | mean rollout reward: 27.75 | global_step: 6389760
# SPS: 2174 | episode: 391 | mean rollout reward: 27.0 | global_step: 6406144
# SPS: 2169 | episode: 392 | mean rollout reward: 26.375 | global_step: 6422528
# SPS: 2169 | episode: 393 | mean rollout reward: 30.75 | global_step: 6438912
# SPS: 2168 | episode: 394 | mean rollout reward: 35.25 | global_step: 6455296
# SPS: 2168 | episode: 395 | mean rollout reward: 41.875 | global_step: 6471680
# SPS: 2168 | episode: 396 | mean rollout reward: 44.875 | global_step: 6488064
# SPS: 2167 | episode: 397 | mean rollout reward: 26.5 | global_step: 6504448
# SPS: 2167 | episode: 398 | mean rollout reward: 19.875 | global_step: 6520832
# SPS: 2166 | episode: 399 | mean rollout reward: 21.875 | global_step: 6537216
# SPS: 2166 | episode: 400 | mean rollout reward: 32.25 | global_step: 6553600
# SPS: 2165 | episode: 401 | mean rollout reward: 33.0 | global_step: 6569984
# SPS: 2165 | episode: 402 | mean rollout reward: 34.375 | global_step: 6586368
# SPS: 2164 | episode: 403 | mean rollout reward: 42.125 | global_step: 6602752
# SPS: 2164 | episode: 404 | mean rollout reward: 38.25 | global_step: 6619136
# SPS: 2164 | episode: 405 | mean rollout reward: 31.5 | global_step: 6635520
# SPS: 2163 | episode: 406 | mean rollout reward: 28.875 | global_step: 6651904
# SPS: 2163 | episode: 407 | mean rollout reward: 26.0 | global_step: 6668288
# SPS: 2162 | episode: 408 | mean rollout reward: 21.25 | global_step: 6684672
# SPS: 2161 | episode: 409 | mean rollout reward: 29.0 | global_step: 6701056
# SPS: 2161 | episode: 410 | mean rollout reward: 31.75 | global_step: 6717440
# SPS: 2161 | episode: 411 | mean rollout reward: 26.75 | global_step: 6733824
# SPS: 2160 | episode: 412 | mean rollout reward: 34.625 | global_step: 6750208
# SPS: 2159 | episode: 413 | mean rollout reward: 25.875 | global_step: 6766592
# SPS: 2159 | episode: 414 | mean rollout reward: 30.875 | global_step: 6782976
# SPS: 2158 | episode: 415 | mean rollout reward: 34.25 | global_step: 6799360
# SPS: 2157 | episode: 416 | mean rollout reward: 31.25 | global_step: 6815744
# SPS: 2157 | episode: 417 | mean rollout reward: 30.125 | global_step: 6832128
# SPS: 2157 | episode: 418 | mean rollout reward: 23.0 | global_step: 6848512
# SPS: 2157 | episode: 419 | mean rollout reward: 27.625 | global_step: 6864896
# SPS: 2157 | episode: 420 | mean rollout reward: 29.375 | global_step: 6881280
# SPS: 2157 | episode: 421 | mean rollout reward: 26.75 | global_step: 6897664
# SPS: 2157 | episode: 422 | mean rollout reward: 24.75 | global_step: 6914048
# SPS: 2157 | episode: 423 | mean rollout reward: 27.5 | global_step: 6930432
# SPS: 2156 | episode: 424 | mean rollout reward: 31.625 | global_step: 6946816
# SPS: 2156 | episode: 425 | mean rollout reward: 29.0 | global_step: 6963200
# SPS: 2156 | episode: 426 | mean rollout reward: 35.125 | global_step: 6979584
# SPS: 2157 | episode: 427 | mean rollout reward: 28.25 | global_step: 6995968
# SPS: 2157 | episode: 428 | mean rollout reward: 27.5 | global_step: 7012352
# SPS: 2157 | episode: 429 | mean rollout reward: 32.0 | global_step: 7028736
# SPS: 2157 | episode: 430 | mean rollout reward: 22.875 | global_step: 7045120
# SPS: 2157 | episode: 431 | mean rollout reward: 29.375 | global_step: 7061504
# SPS: 2157 | episode: 432 | mean rollout reward: 34.75 | global_step: 7077888
# SPS: 2157 | episode: 433 | mean rollout reward: 31.75 | global_step: 7094272
# SPS: 2158 | episode: 434 | mean rollout reward: 36.0 | global_step: 7110656
# SPS: 2158 | episode: 435 | mean rollout reward: 37.375 | global_step: 7127040
# SPS: 2158 | episode: 436 | mean rollout reward: 32.125 | global_step: 7143424
# SPS: 2158 | episode: 437 | mean rollout reward: 24.875 | global_step: 7159808
# SPS: 2158 | episode: 438 | mean rollout reward: 27.625 | global_step: 7176192
# SPS: 2159 | episode: 439 | mean rollout reward: 26.875 | global_step: 7192576
# SPS: 2159 | episode: 440 | mean rollout reward: 27.875 | global_step: 7208960
# SPS: 2159 | episode: 441 | mean rollout reward: 29.0 | global_step: 7225344
# SPS: 2159 | episode: 442 | mean rollout reward: 26.125 | global_step: 7241728
# SPS: 2160 | episode: 443 | mean rollout reward: 34.0 | global_step: 7258112
# SPS: 2160 | episode: 444 | mean rollout reward: 26.125 | global_step: 7274496
# SPS: 2160 | episode: 445 | mean rollout reward: 31.25 | global_step: 7290880
# SPS: 2160 | episode: 446 | mean rollout reward: 30.625 | global_step: 7307264
# SPS: 2161 | episode: 447 | mean rollout reward: 23.5 | global_step: 7323648
# SPS: 2161 | episode: 448 | mean rollout reward: 28.125 | global_step: 7340032
# SPS: 2160 | episode: 449 | mean rollout reward: 24.0 | global_step: 7356416
# SPS: 2160 | episode: 450 | mean rollout reward: 29.875 | global_step: 7372800
# SPS: 2161 | episode: 451 | mean rollout reward: 30.875 | global_step: 7389184
# SPS: 2161 | episode: 452 | mean rollout reward: 24.75 | global_step: 7405568
# SPS: 2161 | episode: 453 | mean rollout reward: 24.75 | global_step: 7421952
# SPS: 2161 | episode: 454 | mean rollout reward: 35.875 | global_step: 7438336
# SPS: 2162 | episode: 455 | mean rollout reward: 27.375 | global_step: 7454720
# SPS: 2162 | episode: 456 | mean rollout reward: 25.25 | global_step: 7471104
# SPS: 2162 | episode: 457 | mean rollout reward: 37.125 | global_step: 7487488
# SPS: 2162 | episode: 458 | mean rollout reward: 38.375 | global_step: 7503872
# SPS: 2163 | episode: 459 | mean rollout reward: 30.0 | global_step: 7520256
# SPS: 2163 | episode: 460 | mean rollout reward: 29.125 | global_step: 7536640
# SPS: 2163 | episode: 461 | mean rollout reward: 27.5 | global_step: 7553024
# SPS: 2163 | episode: 462 | mean rollout reward: 28.625 | global_step: 7569408
# SPS: 2163 | episode: 463 | mean rollout reward: 27.5 | global_step: 7585792
# SPS: 2163 | episode: 464 | mean rollout reward: 21.5 | global_step: 7602176
# SPS: 2163 | episode: 465 | mean rollout reward: 29.75 | global_step: 7618560
# SPS: 2164 | episode: 466 | mean rollout reward: 32.5 | global_step: 7634944
# SPS: 2164 | episode: 467 | mean rollout reward: 31.5 | global_step: 7651328
# SPS: 2164 | episode: 468 | mean rollout reward: 29.5 | global_step: 7667712
# SPS: 2164 | episode: 469 | mean rollout reward: 27.25 | global_step: 7684096
# SPS: 2164 | episode: 470 | mean rollout reward: 29.625 | global_step: 7700480
# SPS: 2164 | episode: 471 | mean rollout reward: 24.875 | global_step: 7716864
# SPS: 2164 | episode: 472 | mean rollout reward: 25.375 | global_step: 7733248
# SPS: 2164 | episode: 473 | mean rollout reward: 29.375 | global_step: 7749632
# SPS: 2164 | episode: 474 | mean rollout reward: 28.5 | global_step: 7766016
# SPS: 2164 | episode: 475 | mean rollout reward: 28.875 | global_step: 7782400
# SPS: 2164 | episode: 476 | mean rollout reward: 31.375 | global_step: 7798784
# SPS: 2164 | episode: 477 | mean rollout reward: 32.125 | global_step: 7815168
# SPS: 2164 | episode: 478 | mean rollout reward: 30.875 | global_step: 7831552
# SPS: 2164 | episode: 479 | mean rollout reward: 26.75 | global_step: 7847936
# SPS: 2164 | episode: 480 | mean rollout reward: 31.375 | global_step: 7864320
# SPS: 2164 | episode: 481 | mean rollout reward: 34.75 | global_step: 7880704
# SPS: 2164 | episode: 482 | mean rollout reward: 41.125 | global_step: 7897088
# SPS: 2165 | episode: 483 | mean rollout reward: 33.0 | global_step: 7913472
# SPS: 2165 | episode: 484 | mean rollout reward: 30.25 | global_step: 7929856
# SPS: 2165 | episode: 485 | mean rollout reward: 31.375 | global_step: 7946240
# SPS: 2165 | episode: 486 | mean rollout reward: 30.0 | global_step: 7962624
# SPS: 2166 | episode: 487 | mean rollout reward: 28.375 | global_step: 7979008
# SPS: 2166 | episode: 488 | mean rollout reward: 32.0 | global_step: 7995392
# SPS: 2166 | episode: 489 | mean rollout reward: 42.375 | global_step: 8011776
# SPS: 2166 | episode: 490 | mean rollout reward: 28.375 | global_step: 8028160
# SPS: 2167 | episode: 491 | mean rollout reward: 24.625 | global_step: 8044544
# SPS: 2167 | episode: 492 | mean rollout reward: 25.5 | global_step: 8060928
# SPS: 2167 | episode: 493 | mean rollout reward: 34.0 | global_step: 8077312
# SPS: 2167 | episode: 494 | mean rollout reward: 33.75 | global_step: 8093696
# SPS: 2167 | episode: 495 | mean rollout reward: 29.75 | global_step: 8110080
# SPS: 2167 | episode: 496 | mean rollout reward: 28.875 | global_step: 8126464
# SPS: 2168 | episode: 497 | mean rollout reward: 27.625 | global_step: 8142848
# SPS: 2168 | episode: 498 | mean rollout reward: 26.625 | global_step: 8159232
# SPS: 2168 | episode: 499 | mean rollout reward: 34.875 | global_step: 8175616
# SPS: 2168 | episode: 500 | mean rollout reward: 37.25 | global_step: 8192000
# SPS: 2168 | episode: 501 | mean rollout reward: 35.125 | global_step: 8208384
# SPS: 2168 | episode: 502 | mean rollout reward: 25.75 | global_step: 8224768
# SPS: 2169 | episode: 503 | mean rollout reward: 25.875 | global_step: 8241152
# SPS: 2169 | episode: 504 | mean rollout reward: 25.75 | global_step: 8257536
# SPS: 2169 | episode: 505 | mean rollout reward: 21.0 | global_step: 8273920
# SPS: 2169 | episode: 506 | mean rollout reward: 28.5 | global_step: 8290304
# SPS: 2169 | episode: 507 | mean rollout reward: 25.625 | global_step: 8306688
# SPS: 2169 | episode: 508 | mean rollout reward: 28.625 | global_step: 8323072
# SPS: 2169 | episode: 509 | mean rollout reward: 26.625 | global_step: 8339456
# SPS: 2169 | episode: 510 | mean rollout reward: 32.625 | global_step: 8355840
# SPS: 2170 | episode: 511 | mean rollout reward: 32.875 | global_step: 8372224
# SPS: 2170 | episode: 512 | mean rollout reward: 33.25 | global_step: 8388608
# SPS: 2170 | episode: 513 | mean rollout reward: 36.5 | global_step: 8404992
# SPS: 2170 | episode: 514 | mean rollout reward: 31.5 | global_step: 8421376
# SPS: 2170 | episode: 515 | mean rollout reward: 33.875 | global_step: 8437760
# SPS: 2170 | episode: 516 | mean rollout reward: 28.625 | global_step: 8454144
# SPS: 2171 | episode: 517 | mean rollout reward: 29.375 | global_step: 8470528
# SPS: 2171 | episode: 518 | mean rollout reward: 30.875 | global_step: 8486912
# SPS: 2171 | episode: 519 | mean rollout reward: 28.375 | global_step: 8503296
# SPS: 2171 | episode: 520 | mean rollout reward: 28.375 | global_step: 8519680
# SPS: 2171 | episode: 521 | mean rollout reward: 26.875 | global_step: 8536064
# SPS: 2171 | episode: 522 | mean rollout reward: 30.875 | global_step: 8552448
# SPS: 2171 | episode: 523 | mean rollout reward: 29.375 | global_step: 8568832
# SPS: 2171 | episode: 524 | mean rollout reward: 32.375 | global_step: 8585216
# SPS: 2171 | episode: 525 | mean rollout reward: 30.625 | global_step: 8601600
# SPS: 2172 | episode: 526 | mean rollout reward: 29.875 | global_step: 8617984
# SPS: 2172 | episode: 527 | mean rollout reward: 31.5 | global_step: 8634368
# SPS: 2172 | episode: 528 | mean rollout reward: 31.75 | global_step: 8650752
# SPS: 2172 | episode: 529 | mean rollout reward: 32.625 | global_step: 8667136
# SPS: 2172 | episode: 530 | mean rollout reward: 33.375 | global_step: 8683520
# SPS: 2172 | episode: 531 | mean rollout reward: 34.5 | global_step: 8699904
# SPS: 2172 | episode: 532 | mean rollout reward: 33.0 | global_step: 8716288
# SPS: 2173 | episode: 533 | mean rollout reward: 31.625 | global_step: 8732672
# SPS: 2173 | episode: 534 | mean rollout reward: 24.875 | global_step: 8749056
# SPS: 2173 | episode: 535 | mean rollout reward: 26.0 | global_step: 8765440
# SPS: 2173 | episode: 536 | mean rollout reward: 24.5 | global_step: 8781824
# SPS: 2173 | episode: 537 | mean rollout reward: 34.625 | global_step: 8798208
# SPS: 2174 | episode: 538 | mean rollout reward: 33.375 | global_step: 8814592
# SPS: 2174 | episode: 539 | mean rollout reward: 34.625 | global_step: 8830976
# SPS: 2174 | episode: 540 | mean rollout reward: 31.0 | global_step: 8847360
# SPS: 2174 | episode: 541 | mean rollout reward: 29.375 | global_step: 8863744
# SPS: 2174 | episode: 542 | mean rollout reward: 33.875 | global_step: 8880128
# SPS: 2174 | episode: 543 | mean rollout reward: 32.625 | global_step: 8896512
# SPS: 2174 | episode: 544 | mean rollout reward: 33.75 | global_step: 8912896
# SPS: 2174 | episode: 545 | mean rollout reward: 38.75 | global_step: 8929280
# SPS: 2175 | episode: 546 | mean rollout reward: 32.75 | global_step: 8945664
# SPS: 2175 | episode: 547 | mean rollout reward: 27.5 | global_step: 8962048
# SPS: 2175 | episode: 548 | mean rollout reward: 26.0 | global_step: 8978432
# SPS: 2175 | episode: 549 | mean rollout reward: 31.25 | global_step: 8994816
# SPS: 2176 | episode: 550 | mean rollout reward: 33.125 | global_step: 9011200
# SPS: 2176 | episode: 551 | mean rollout reward: 32.25 | global_step: 9027584
# SPS: 2176 | episode: 552 | mean rollout reward: 24.5 | global_step: 9043968
# SPS: 2176 | episode: 553 | mean rollout reward: 24.75 | global_step: 9060352
# SPS: 2176 | episode: 554 | mean rollout reward: 29.625 | global_step: 9076736
# SPS: 2176 | episode: 555 | mean rollout reward: 32.25 | global_step: 9093120
# SPS: 2176 | episode: 556 | mean rollout reward: 39.625 | global_step: 9109504
# SPS: 2176 | episode: 557 | mean rollout reward: 27.375 | global_step: 9125888
# SPS: 2177 | episode: 558 | mean rollout reward: 27.25 | global_step: 9142272
# SPS: 2177 | episode: 559 | mean rollout reward: 27.875 | global_step: 9158656
# SPS: 2177 | episode: 560 | mean rollout reward: 22.875 | global_step: 9175040
# SPS: 2177 | episode: 561 | mean rollout reward: 29.625 | global_step: 9191424
# SPS: 2175 | episode: 562 | mean rollout reward: 39.25 | global_step: 9207808
# SPS: 2172 | episode: 563 | mean rollout reward: 32.125 | global_step: 9224192
# SPS: 2172 | episode: 564 | mean rollout reward: 28.125 | global_step: 9240576
# SPS: 2173 | episode: 565 | mean rollout reward: 35.625 | global_step: 9256960
# SPS: 2173 | episode: 566 | mean rollout reward: 38.5 | global_step: 9273344
# SPS: 2173 | episode: 567 | mean rollout reward: 28.75 | global_step: 9289728
# SPS: 2173 | episode: 568 | mean rollout reward: 35.75 | global_step: 9306112
# SPS: 2173 | episode: 569 | mean rollout reward: 34.5 | global_step: 9322496
# SPS: 2173 | episode: 570 | mean rollout reward: 26.0 | global_step: 9338880
# SPS: 2173 | episode: 571 | mean rollout reward: 26.875 | global_step: 9355264
# SPS: 2173 | episode: 572 | mean rollout reward: 27.0 | global_step: 9371648
# SPS: 2174 | episode: 573 | mean rollout reward: 22.875 | global_step: 9388032
# SPS: 2174 | episode: 574 | mean rollout reward: 29.875 | global_step: 9404416
# SPS: 2174 | episode: 575 | mean rollout reward: 34.25 | global_step: 9420800
# SPS: 2174 | episode: 576 | mean rollout reward: 27.875 | global_step: 9437184
# SPS: 2174 | episode: 577 | mean rollout reward: 24.375 | global_step: 9453568
# SPS: 2174 | episode: 578 | mean rollout reward: 28.5 | global_step: 9469952
# SPS: 2174 | episode: 579 | mean rollout reward: 28.875 | global_step: 9486336
# SPS: 2175 | episode: 580 | mean rollout reward: 31.75 | global_step: 9502720
# SPS: 2175 | episode: 581 | mean rollout reward: 35.625 | global_step: 9519104
# SPS: 2175 | episode: 582 | mean rollout reward: 31.0 | global_step: 9535488
# SPS: 2175 | episode: 583 | mean rollout reward: 27.5 | global_step: 9551872
# SPS: 2175 | episode: 584 | mean rollout reward: 20.625 | global_step: 9568256
# SPS: 2175 | episode: 585 | mean rollout reward: 24.25 | global_step: 9584640
# SPS: 2175 | episode: 586 | mean rollout reward: 24.0 | global_step: 9601024
# SPS: 2175 | episode: 587 | mean rollout reward: 23.0 | global_step: 9617408
# SPS: 2175 | episode: 588 | mean rollout reward: 28.875 | global_step: 9633792
# SPS: 2176 | episode: 589 | mean rollout reward: 33.125 | global_step: 9650176
# SPS: 2176 | episode: 590 | mean rollout reward: 30.625 | global_step: 9666560
# SPS: 2176 | episode: 591 | mean rollout reward: 27.75 | global_step: 9682944
# SPS: 2176 | episode: 592 | mean rollout reward: 28.375 | global_step: 9699328
# SPS: 2176 | episode: 593 | mean rollout reward: 25.0 | global_step: 9715712
# SPS: 2176 | episode: 594 | mean rollout reward: 35.125 | global_step: 9732096
# SPS: 2177 | episode: 595 | mean rollout reward: 37.625 | global_step: 9748480
# SPS: 2177 | episode: 596 | mean rollout reward: 34.0 | global_step: 9764864
# SPS: 2177 | episode: 597 | mean rollout reward: 34.25 | global_step: 9781248
# SPS: 2177 | episode: 598 | mean rollout reward: 27.0 | global_step: 9797632
# SPS: 2177 | episode: 599 | mean rollout reward: 30.0 | global_step: 9814016
# SPS: 2177 | episode: 600 | mean rollout reward: 30.25 | global_step: 9830400
# SPS: 2177 | episode: 601 | mean rollout reward: 34.125 | global_step: 9846784
# SPS: 2177 | episode: 602 | mean rollout reward: 32.5 | global_step: 9863168
# SPS: 2177 | episode: 603 | mean rollout reward: 34.125 | global_step: 9879552
# SPS: 2177 | episode: 604 | mean rollout reward: 30.625 | global_step: 9895936
# SPS: 2177 | episode: 605 | mean rollout reward: 34.125 | global_step: 9912320
# SPS: 2177 | episode: 606 | mean rollout reward: 34.625 | global_step: 9928704
# SPS: 2177 | episode: 607 | mean rollout reward: 31.0 | global_step: 9945088
# SPS: 2177 | episode: 608 | mean rollout reward: 30.25 | global_step: 9961472
# SPS: 2177 | episode: 609 | mean rollout reward: 26.625 | global_step: 9977856
# SPS: 2178 | episode: 610 | mean rollout reward: 28.25 | global_step: 9994240
# SPS: 2178 | episode: 611 | mean rollout reward: 28.375 | global_step: 10010624
# SPS: 2178 | episode: 612 | mean rollout reward: 34.25 | global_step: 10027008
# SPS: 2178 | episode: 613 | mean rollout reward: 29.375 | global_step: 10043392
# SPS: 2178 | episode: 614 | mean rollout reward: 26.5 | global_step: 10059776
# SPS: 2178 | episode: 615 | mean rollout reward: 20.625 | global_step: 10076160
# SPS: 2178 | episode: 616 | mean rollout reward: 26.125 | global_step: 10092544
# SPS: 2178 | episode: 617 | mean rollout reward: 34.375 | global_step: 10108928
# SPS: 2178 | episode: 618 | mean rollout reward: 41.625 | global_step: 10125312
# SPS: 2178 | episode: 619 | mean rollout reward: 39.375 | global_step: 10141696
# SPS: 2178 | episode: 620 | mean rollout reward: 26.25 | global_step: 10158080
# SPS: 2178 | episode: 621 | mean rollout reward: 29.625 | global_step: 10174464
# SPS: 2179 | episode: 622 | mean rollout reward: 22.25 | global_step: 10190848
# SPS: 2179 | episode: 623 | mean rollout reward: 27.5 | global_step: 10207232
# ...
# SPS: 2188 | episode: 797 | mean rollout reward: 24.75 | global_step: 13058048
# SPS: 2188 | episode: 798 | mean rollout reward: 27.25 | global_step: 13074432
# SPS: 2188 | episode: 799 | mean rollout reward: 24.25 | global_step: 13090816
# SPS: 2189 | episode: 800 | mean rollout reward: 30.75 | global_step: 13107200
# SPS: 2189 | episode: 801 | mean rollout reward: 33.5 | global_step: 13123584
# SPS: 2189 | episode: 802 | mean rollout reward: 33.0 | global_step: 13139968
# SPS: 2189 | episode: 803 | mean rollout reward: 28.75 | global_step: 13156352
# SPS: 2189 | episode: 804 | mean rollout reward: 28.25 | global_step: 13172736
# SPS: 2189 | episode: 805 | mean rollout reward: 25.25 | global_step: 13189120
# SPS: 2190 | episode: 806 | mean rollout reward: 26.625 | global_step: 13205504
# SPS: 2190 | episode: 807 | mean rollout reward: 24.625 | global_step: 13221888
# SPS: 2190 | episode: 808 | mean rollout reward: 23.125 | global_step: 13238272
# SPS: 2190 | episode: 809 | mean rollout reward: 34.75 | global_step: 13254656
# SPS: 2190 | episode: 810 | mean rollout reward: 31.0 | global_step: 13271040
# SPS: 2190 | episode: 811 | mean rollout reward: 26.25 | global_step: 13287424
# SPS: 2190 | episode: 812 | mean rollout reward: 30.375 | global_step: 13303808
# SPS: 2190 | episode: 813 | mean rollout reward: 22.25 | global_step: 13320192
# SPS: 2190 | episode: 814 | mean rollout reward: 20.625 | global_step: 13336576
# SPS: 2190 | episode: 815 | mean rollout reward: 22.375 | global_step: 13352960
# SPS: 2190 | episode: 816 | mean rollout reward: 37.5 | global_step: 13369344
# SPS: 2190 | episode: 817 | mean rollout reward: 30.75 | global_step: 13385728
# SPS: 2190 | episode: 818 | mean rollout reward: 27.0 | global_step: 13402112
# SPS: 2191 | episode: 819 | mean rollout reward: 27.375 | global_step: 13418496
# SPS: 2191 | episode: 820 | mean rollout reward: 25.125 | global_step: 13434880
# SPS: 2191 | episode: 821 | mean rollout reward: 26.5 | global_step: 13451264
# SPS: 2191 | episode: 822 | mean rollout reward: 25.75 | global_step: 13467648
# SPS: 2191 | episode: 823 | mean rollout reward: 30.375 | global_step: 13484032
# SPS: 2191 | episode: 824 | mean rollout reward: 33.875 | global_step: 13500416
# SPS: 2191 | episode: 825 | mean rollout reward: 30.875 | global_step: 13516800
# SPS: 2192 | episode: 826 | mean rollout reward: 33.75 | global_step: 13533184
# SPS: 2192 | episode: 827 | mean rollout reward: 30.0 | global_step: 13549568
# SPS: 2192 | episode: 828 | mean rollout reward: 26.875 | global_step: 13565952
# SPS: 2192 | episode: 829 | mean rollout reward: 32.625 | global_step: 13582336
# SPS: 2192 | episode: 830 | mean rollout reward: 29.125 | global_step: 13598720
# SPS: 2192 | episode: 831 | mean rollout reward: 25.5 | global_step: 13615104
# SPS: 2192 | episode: 832 | mean rollout reward: 26.25 | global_step: 13631488
# SPS: 2192 | episode: 833 | mean rollout reward: 28.25 | global_step: 13647872
# SPS: 2192 | episode: 834 | mean rollout reward: 23.5 | global_step: 13664256
# SPS: 2192 | episode: 835 | mean rollout reward: 28.25 | global_step: 13680640
# SPS: 2192 | episode: 836 | mean rollout reward: 20.0 | global_step: 13697024
# SPS: 2192 | episode: 837 | mean rollout reward: 28.625 | global_step: 13713408
# SPS: 2192 | episode: 838 | mean rollout reward: 29.875 | global_step: 13729792
# SPS: 2192 | episode: 839 | mean rollout reward: 23.625 | global_step: 13746176
# SPS: 2192 | episode: 840 | mean rollout reward: 20.5 | global_step: 13762560
# SPS: 2192 | episode: 841 | mean rollout reward: 23.375 | global_step: 13778944
# SPS: 2193 | episode: 842 | mean rollout reward: 33.25 | global_step: 13795328
# SPS: 2193 | episode: 843 | mean rollout reward: 27.125 | global_step: 13811712
# SPS: 2193 | episode: 844 | mean rollout reward: 29.25 | global_step: 13828096
# SPS: 2193 | episode: 845 | mean rollout reward: 26.75 | global_step: 13844480
# SPS: 2193 | episode: 846 | mean rollout reward: 32.625 | global_step: 13860864
# SPS: 2193 | episode: 847 | mean rollout reward: 35.75 | global_step: 13877248
# SPS: 2193 | episode: 848 | mean rollout reward: 38.125 | global_step: 13893632
# SPS: 2194 | episode: 849 | mean rollout reward: 29.25 | global_step: 13910016
# SPS: 2194 | episode: 850 | mean rollout reward: 21.625 | global_step: 13926400
# SPS: 2194 | episode: 851 | mean rollout reward: 31.625 | global_step: 13942784
# SPS: 2194 | episode: 852 | mean rollout reward: 35.25 | global_step: 13959168
# SPS: 2194 | episode: 853 | mean rollout reward: 39.375 | global_step: 13975552
# SPS: 2194 | episode: 854 | mean rollout reward: 32.875 | global_step: 13991936
# SPS: 2194 | episode: 855 | mean rollout reward: 31.125 | global_step: 14008320
# SPS: 2194 | episode: 856 | mean rollout reward: 27.0 | global_step: 14024704
# SPS: 2194 | episode: 857 | mean rollout reward: 24.125 | global_step: 14041088
# SPS: 2195 | episode: 858 | mean rollout reward: 22.25 | global_step: 14057472
# SPS: 2195 | episode: 859 | mean rollout reward: 22.5 | global_step: 14073856
# SPS: 2195 | episode: 860 | mean rollout reward: 35.375 | global_step: 14090240
# SPS: 2195 | episode: 861 | mean rollout reward: 28.75 | global_step: 14106624
# SPS: 2195 | episode: 862 | mean rollout reward: 22.125 | global_step: 14123008
# SPS: 2195 | episode: 863 | mean rollout reward: 35.5 | global_step: 14139392
# SPS: 2195 | episode: 864 | mean rollout reward: 28.625 | global_step: 14155776
# SPS: 2195 | episode: 865 | mean rollout reward: 25.625 | global_step: 14172160
# SPS: 2195 | episode: 866 | mean rollout reward: 22.625 | global_step: 14188544
# SPS: 2196 | episode: 867 | mean rollout reward: 26.25 | global_step: 14204928
# SPS: 2196 | episode: 868 | mean rollout reward: 24.125 | global_step: 14221312
# SPS: 2196 | episode: 869 | mean rollout reward: 25.125 | global_step: 14237696
# SPS: 2196 | episode: 870 | mean rollout reward: 29.125 | global_step: 14254080
# SPS: 2196 | episode: 871 | mean rollout reward: 25.625 | global_step: 14270464
# SPS: 2196 | episode: 872 | mean rollout reward: 27.25 | global_step: 14286848
# SPS: 2196 | episode: 873 | mean rollout reward: 21.25 | global_step: 14303232
# SPS: 2196 | episode: 874 | mean rollout reward: 26.125 | global_step: 14319616
# SPS: 2196 | episode: 875 | mean rollout reward: 24.375 | global_step: 14336000
# SPS: 2197 | episode: 876 | mean rollout reward: 30.375 | global_step: 14352384
# SPS: 2197 | episode: 877 | mean rollout reward: 26.875 | global_step: 14368768
# SPS: 2197 | episode: 878 | mean rollout reward: 32.875 | global_step: 14385152
# SPS: 2197 | episode: 879 | mean rollout reward: 28.25 | global_step: 14401536
# SPS: 2197 | episode: 880 | mean rollout reward: 25.375 | global_step: 14417920
# SPS: 2197 | episode: 881 | mean rollout reward: 26.0 | global_step: 14434304
# SPS: 2197 | episode: 882 | mean rollout reward: 28.5 | global_step: 14450688
# SPS: 2197 | episode: 883 | mean rollout reward: 39.125 | global_step: 14467072
# SPS: 2197 | episode: 884 | mean rollout reward: 32.375 | global_step: 14483456
# SPS: 2197 | episode: 885 | mean rollout reward: 32.75 | global_step: 14499840
# SPS: 2197 | episode: 886 | mean rollout reward: 33.625 | global_step: 14516224
# SPS: 2197 | episode: 887 | mean rollout reward: 21.25 | global_step: 14532608
# SPS: 2198 | episode: 888 | mean rollout reward: 27.0 | global_step: 14548992
# SPS: 2198 | episode: 889 | mean rollout reward: 25.125 | global_step: 14565376
# SPS: 2198 | episode: 890 | mean rollout reward: 26.125 | global_step: 14581760
# SPS: 2198 | episode: 891 | mean rollout reward: 25.25 | global_step: 14598144
# SPS: 2198 | episode: 892 | mean rollout reward: 28.75 | global_step: 14614528
# SPS: 2198 | episode: 893 | mean rollout reward: 29.125 | global_step: 14630912
# SPS: 2198 | episode: 894 | mean rollout reward: 33.25 | global_step: 14647296
# SPS: 2198 | episode: 895 | mean rollout reward: 31.625 | global_step: 14663680
# SPS: 2198 | episode: 896 | mean rollout reward: 26.875 | global_step: 14680064
# SPS: 2198 | episode: 897 | mean rollout reward: 32.375 | global_step: 14696448
# SPS: 2198 | episode: 898 | mean rollout reward: 25.875 | global_step: 14712832
# SPS: 2199 | episode: 899 | mean rollout reward: 31.625 | global_step: 14729216
# SPS: 2199 | episode: 900 | mean rollout reward: 24.125 | global_step: 14745600
# SPS: 2199 | episode: 901 | mean rollout reward: 30.875 | global_step: 14761984
# SPS: 2199 | episode: 902 | mean rollout reward: 35.25 | global_step: 14778368
# SPS: 2199 | episode: 903 | mean rollout reward: 32.75 | global_step: 14794752
# SPS: 2199 | episode: 904 | mean rollout reward: 34.5 | global_step: 14811136
# SPS: 2199 | episode: 905 | mean rollout reward: 26.875 | global_step: 14827520
# SPS: 2199 | episode: 906 | mean rollout reward: 20.875 | global_step: 14843904
# SPS: 2199 | episode: 907 | mean rollout reward: 25.25 | global_step: 14860288
# SPS: 2199 | episode: 908 | mean rollout reward: 37.875 | global_step: 14876672
# SPS: 2199 | episode: 909 | mean rollout reward: 33.125 | global_step: 14893056
# SPS: 2200 | episode: 910 | mean rollout reward: 38.375 | global_step: 14909440
# SPS: 2200 | episode: 911 | mean rollout reward: 38.375 | global_step: 14925824
# SPS: 2200 | episode: 912 | mean rollout reward: 32.625 | global_step: 14942208
# SPS: 2200 | episode: 913 | mean rollout reward: 27.625 | global_step: 14958592
# SPS: 2200 | episode: 914 | mean rollout reward: 22.0 | global_step: 14974976
# SPS: 2200 | episode: 915 | mean rollout reward: 24.875 | global_step: 14991360
# SPS: 2200 | episode: 916 | mean rollout reward: 38.125 | global_step: 15007744
# SPS: 2200 | episode: 917 | mean rollout reward: 32.625 | global_step: 15024128
# SPS: 2200 | episode: 918 | mean rollout reward: 29.0 | global_step: 15040512
# SPS: 2201 | episode: 919 | mean rollout reward: 27.875 | global_step: 15056896
# SPS: 2200 | episode: 920 | mean rollout reward: 30.125 | global_step: 15073280
# SPS: 2198 | episode: 921 | mean rollout reward: 25.75 | global_step: 15089664
# SPS: 2198 | episode: 922 | mean rollout reward: 25.25 | global_step: 15106048
# SPS: 2197 | episode: 923 | mean rollout reward: 23.5 | global_step: 15122432
# SPS: 2197 | episode: 924 | mean rollout reward: 34.375 | global_step: 15138816
# SPS: 2197 | episode: 925 | mean rollout reward: 39.125 | global_step: 15155200
# SPS: 2197 | episode: 926 | mean rollout reward: 32.25 | global_step: 15171584
# SPS: 2197 | episode: 927 | mean rollout reward: 27.0 | global_step: 15187968
# SPS: 2197 | episode: 928 | mean rollout reward: 40.0 | global_step: 15204352
# SPS: 2198 | episode: 929 | mean rollout reward: 30.0 | global_step: 15220736
# SPS: 2198 | episode: 930 | mean rollout reward: 32.0 | global_step: 15237120
# SPS: 2198 | episode: 931 | mean rollout reward: 29.625 | global_step: 15253504
# SPS: 2198 | episode: 932 | mean rollout reward: 26.25 | global_step: 15269888
# SPS: 2198 | episode: 933 | mean rollout reward: 29.75 | global_step: 15286272
# SPS: 2198 | episode: 934 | mean rollout reward: 28.125 | global_step: 15302656
# SPS: 2198 | episode: 935 | mean rollout reward: 28.375 | global_step: 15319040
# SPS: 2198 | episode: 936 | mean rollout reward: 27.625 | global_step: 15335424
# SPS: 2198 | episode: 937 | mean rollout reward: 33.75 | global_step: 15351808
# SPS: 2198 | episode: 938 | mean rollout reward: 33.625 | global_step: 15368192
# SPS: 2198 | episode: 939 | mean rollout reward: 33.0 | global_step: 15384576
# SPS: 2198 | episode: 940 | mean rollout reward: 30.0 | global_step: 15400960
# SPS: 2198 | episode: 941 | mean rollout reward: 28.75 | global_step: 15417344
# SPS: 2198 | episode: 942 | mean rollout reward: 25.375 | global_step: 15433728
# SPS: 2198 | episode: 943 | mean rollout reward: 28.75 | global_step: 15450112
# SPS: 2198 | episode: 944 | mean rollout reward: 30.25 | global_step: 15466496
# SPS: 2198 | episode: 945 | mean rollout reward: 24.125 | global_step: 15482880
# SPS: 2198 | episode: 946 | mean rollout reward: 26.0 | global_step: 15499264
# SPS: 2198 | episode: 947 | mean rollout reward: 28.75 | global_step: 15515648
# SPS: 2198 | episode: 948 | mean rollout reward: 33.0 | global_step: 15532032
# SPS: 2198 | episode: 949 | mean rollout reward: 31.625 | global_step: 15548416
# SPS: 2198 | episode: 950 | mean rollout reward: 26.125 | global_step: 15564800
# SPS: 2198 | episode: 951 | mean rollout reward: 27.375 | global_step: 15581184
# SPS: 2198 | episode: 952 | mean rollout reward: 24.5 | global_step: 15597568
# SPS: 2198 | episode: 953 | mean rollout reward: 23.875 | global_step: 15613952
# SPS: 2198 | episode: 954 | mean rollout reward: 34.375 | global_step: 15630336
# SPS: 2198 | episode: 955 | mean rollout reward: 28.125 | global_step: 15646720
# SPS: 2198 | episode: 956 | mean rollout reward: 25.875 | global_step: 15663104
# SPS: 2198 | episode: 957 | mean rollout reward: 29.25 | global_step: 15679488
# SPS: 2198 | episode: 958 | mean rollout reward: 37.625 | global_step: 15695872
# SPS: 2198 | episode: 959 | mean rollout reward: 34.75 | global_step: 15712256
# SPS: 2198 | episode: 960 | mean rollout reward: 32.125 | global_step: 15728640
# SPS: 2198 | episode: 961 | mean rollout reward: 24.625 | global_step: 15745024
# SPS: 2198 | episode: 962 | mean rollout reward: 33.625 | global_step: 15761408
# SPS: 2198 | episode: 963 | mean rollout reward: 26.75 | global_step: 15777792
# SPS: 2198 | episode: 964 | mean rollout reward: 34.5 | global_step: 15794176
# SPS: 2198 | episode: 965 | mean rollout reward: 37.0 | global_step: 15810560
# SPS: 2198 | episode: 966 | mean rollout reward: 32.875 | global_step: 15826944
# SPS: 2198 | episode: 967 | mean rollout reward: 23.375 | global_step: 15843328
# SPS: 2198 | episode: 968 | mean rollout reward: 24.25 | global_step: 15859712
# SPS: 2198 | episode: 969 | mean rollout reward: 35.25 | global_step: 15876096
# SPS: 2198 | episode: 970 | mean rollout reward: 33.25 | global_step: 15892480
# SPS: 2198 | episode: 971 | mean rollout reward: 29.125 | global_step: 15908864
# SPS: 2198 | episode: 972 | mean rollout reward: 31.75 | global_step: 15925248
# SPS: 2197 | episode: 973 | mean rollout reward: 26.875 | global_step: 15941632
# SPS: 2197 | episode: 974 | mean rollout reward: 26.375 | global_step: 15958016
# SPS: 2197 | episode: 975 | mean rollout reward: 20.875 | global_step: 15974400
# SPS: 2197 | episode: 976 | mean rollout reward: 32.125 | global_step: 15990784
# SPS: 2197 | episode: 977 | mean rollout reward: 35.375 | global_step: 16007168
# SPS: 2197 | episode: 978 | mean rollout reward: 28.125 | global_step: 16023552
# SPS: 2197 | episode: 979 | mean rollout reward: 23.75 | global_step: 16039936
# SPS: 2197 | episode: 980 | mean rollout reward: 28.0 | global_step: 16056320
# SPS: 2197 | episode: 981 | mean rollout reward: 32.875 | global_step: 16072704
# SPS: 2197 | episode: 982 | mean rollout reward: 32.75 | global_step: 16089088
# SPS: 2197 | episode: 983 | mean rollout reward: 27.875 | global_step: 16105472
# SPS: 2197 | episode: 984 | mean rollout reward: 25.0 | global_step: 16121856
# SPS: 2197 | episode: 985 | mean rollout reward: 35.5 | global_step: 16138240
# SPS: 2197 | episode: 986 | mean rollout reward: 29.125 | global_step: 16154624
# SPS: 2197 | episode: 987 | mean rollout reward: 30.75 | global_step: 16171008
# SPS: 2197 | episode: 988 | mean rollout reward: 35.75 | global_step: 16187392
# SPS: 2197 | episode: 989 | mean rollout reward: 29.375 | global_step: 16203776
# SPS: 2197 | episode: 990 | mean rollout reward: 28.625 | global_step: 16220160
# SPS: 2197 | episode: 991 | mean rollout reward: 30.5 | global_step: 16236544
# SPS: 2197 | episode: 992 | mean rollout reward: 34.75 | global_step: 16252928
# SPS: 2197 | episode: 993 | mean rollout reward: 22.5 | global_step: 16269312
# SPS: 2197 | episode: 994 | mean rollout reward: 28.875 | global_step: 16285696
# SPS: 2196 | episode: 995 | mean rollout reward: 29.0 | global_step: 16302080
# SPS: 2196 | episode: 996 | mean rollout reward: 35.625 | global_step: 16318464
# SPS: 2196 | episode: 997 | mean rollout reward: 27.0 | global_step: 16334848
# SPS: 2196 | episode: 998 | mean rollout reward: 20.125 | global_step: 16351232
# SPS: 2196 | episode: 999 | mean rollout reward: 23.5 | global_step: 16367616
# SPS: 2196 | episode: 1000 | mean rollout reward: 22.125 | global_step: 16384000

# %%
torch.save(agent.state_dict(), "../models/ppo/agent-v12.pth")
torch.save(optimizer.state_dict(), "../models/ppo/optimizer-v12.pth")
